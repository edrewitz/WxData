# %%
from wxdata.radar.radar import(
    download_current_single_station_nexrad2_radar_data,
    download_current_multi_station_nexrad2_radar_data
)

# %%
radars = download_current_multi_station_nexrad2_radar_data(['ktyx', 'kokx'])
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
radars
# Out:
# [[<pyart.core.radar.Radar at 0x25488983df0>,
#   <pyart.core.radar.Radar at 0x2548a504070>,
#   <pyart.core.radar.Radar at 0x25488aa47f0>,
#   <pyart.core.radar.Radar at 0x2549b3147f0>,
#   <pyart.core.radar.Radar at 0x25488a84550>,
#   <pyart.core.radar.Radar at 0x25487ac8850>,
#   <pyart.core.radar.Radar at 0x2549b48c550>,
#   <pyart.core.radar.Radar at 0x254906004c0>,
#   <pyart.core.radar.Radar at 0x25495e2c040>,
#   <pyart.core.radar.Radar at 0x25487a87640>,
#   <pyart.core.radar.Radar at 0x25488d784c0>,
#   <pyart.core.radar.Radar at 0x25487970ee0>,
#   <pyart.core.radar.Radar at 0x25495a94bb0>,
#   <pyart.core.radar.Radar at 0x2548f04ffa0>,
#   <pyart.core.radar.Radar at 0x2548b7b02e0>,
#   <pyart.core.radar.Radar at 0x25491af80a0>,
#   <pyart.core.radar.Radar at 0x25491be0160>,
#   <pyart.core.radar.Radar at 0x25488a8fa30>,
#   <pyart.core.radar.Radar at 0x25491ddc0a0>,
#   <pyart.core.radar.Radar at 0x254932ac100>,
#   <pyart.core.radar.Radar at 0x25488ad4580>,
#   <pyart.core.radar.Radar at 0x25492fc41f0>,
#   <pyart.core.radar.Radar at 0x25488b28400>,
#   <pyart.core.radar.Radar at 0x254907d42b0>,
#   <pyart.core.radar.Radar at 0x25488b12e60>,
#   <pyart.core.radar.Radar at 0x25488afccd0>,
#   <pyart.core.radar.Radar at 0x25488aebd30>,
#   <pyart.core.radar.Radar at 0x25488ac2560>,
#   <pyart.core.radar.Radar at 0x25488aa9c30>,
#   <pyart.core.radar.Radar at 0x25488ab50f0>,
#   <pyart.core.radar.Radar at 0x254934b8190>,
#   <pyart.core.radar.Radar at 0x25488981e10>,
#   <pyart.core.radar.Radar at 0x25488a85720>,
#   <pyart.core.radar.Radar at 0x25487ac8370>,
#   <pyart.core.radar.Radar at 0x25485880430>,
#   <pyart.core.radar.Radar at 0x25487cef9d0>,
#   <pyart.core.radar.Radar at 0x254889db250>,
#   <pyart.core.radar.Radar at 0x254878d6a70>,
#   <pyart.core.radar.Radar at 0x25488a914b0>,
#   <pyart.core.radar.Radar at 0x25488ad4ee0>,
#   <pyart.core.radar.Radar at 0x25488b290c0>,
#   <pyart.core.radar.Radar at 0x25488a875e0>],
#  [<pyart.core.radar.Radar at 0x2548b7b1ae0>,
#   <pyart.core.radar.Radar at 0x25492f302b0>,
#   <pyart.core.radar.Radar at 0x25487a87310>,
#   <pyart.core.radar.Radar at 0x25485880400>,
#   <pyart.core.radar.Radar at 0x25491af88e0>,
#   <pyart.core.radar.Radar at 0x25487970ca0>,
#   <pyart.core.radar.Radar at 0x25491be1450>,
#   <pyart.core.radar.Radar at 0x25488d45840>,
#   <pyart.core.radar.Radar at 0x2549b81c580>,
#   <pyart.core.radar.Radar at 0x25488ab51b0>,
#   <pyart.core.radar.Radar at 0x25496265ba0>,
#   <pyart.core.radar.Radar at 0x254962b5de0>,
#   <pyart.core.radar.Radar at 0x25488ac1d50>,
#   <pyart.core.radar.Radar at 0x2549034b7c0>,
#   <pyart.core.radar.Radar at 0x25488afd780>,
#   <pyart.core.radar.Radar at 0x2549054aa70>,
#   <pyart.core.radar.Radar at 0x2548f1559c0>,
#   <pyart.core.radar.Radar at 0x25488aea020>,
#   <pyart.core.radar.Radar at 0x25488aab730>,
#   <pyart.core.radar.Radar at 0x25495fa8af0>,
#   <pyart.core.radar.Radar at 0x2548a404be0>,
#   <pyart.core.radar.Radar at 0x2548b8ec280>,
#   <pyart.core.radar.Radar at 0x25491ddcac0>,
#   <pyart.core.radar.Radar at 0x25491a08d00>,
#   <pyart.core.radar.Radar at 0x2549b950700>,
#   <pyart.core.radar.Radar at 0x254932ac4f0>,
#   <pyart.core.radar.Radar at 0x25489f280d0>,
#   <pyart.core.radar.Radar at 0x25488ad74f0>,
#   <pyart.core.radar.Radar at 0x254959a87c0>,
#   <pyart.core.radar.Radar at 0x25492fc4040>,
#   <pyart.core.radar.Radar at 0x25495ca4130>,
#   <pyart.core.radar.Radar at 0x25488b285b0>,
#   <pyart.core.radar.Radar at 0x25495c649a0>,
#   <pyart.core.radar.Radar at 0x254930e45b0>,
#   <pyart.core.radar.Radar at 0x254907d4190>,
#   <pyart.core.radar.Radar at 0x2548f140310>,
#   <pyart.core.radar.Radar at 0x25488b13bb0>,
#   <pyart.core.radar.Radar at 0x2548bec81f0>,
#   <pyart.core.radar.Radar at 0x2548f19c4c0>,
#   <pyart.core.radar.Radar at 0x254934bbaf0>,
#   <pyart.core.radar.Radar at 0x2549606d0c0>,
#   <pyart.core.radar.Radar at 0x2549034b640>,
#   <pyart.core.radar.Radar at 0x2549b71ca00>]]
