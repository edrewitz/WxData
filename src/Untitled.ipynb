# %%
from wxdata.rtma.rtma import(
    rtma, 
    rtma_comparison
)

# %%
ds = rtma(model='rtma', 
          source='nomads',
          levels=[2],
          variables=['temperature', 'dew point'])
# Out:
# ...
# Writing GRIB messages     |                              | 0/2
# DPT @ 2 m above ground         |                              |   0% [0.00/743k]
# TMP @ 2 m above ground         |                              |   0% [0.00/743k]
# RTMA Download Complete.
# RTMA Data Processing...
# RTMA Data Processing Complete.

# %%
ds
# Out:
# <xarray.Dataset> Size: 120MB
# Dimensions:                  (y: 1597, x: 2345)
# Coordinates:
#     time                     datetime64[ns] 8B 2026-05-12T04:00:00
#     step                     timedelta64[ns] 8B 00:00:00
#     heightAboveGround        float64 8B 2.0
#     latitude                 (y, x) float64 30MB 19.23 19.23 ... 54.38 54.37
#     longitude                (y, x) float64 30MB -126.3 -126.3 ... -59.07 -59.04
#     valid_time               datetime64[ns] 8B 2026-05-12T04:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     2m_temperature           (y, x) float32 15MB 74.46 74.46 ... 35.64 35.19
#     2m_dew_point             (y, x) float32 15MB 67.8 67.8 67.8 ... 34.9 34.9
#     2m_relative_humidity     (y, x) float32 15MB 94.66 94.66 ... 99.35 99.74
#     2m_dew_point_depression  (y, x) float32 15MB 6.66 6.66 6.804 ... 0.738 0.288
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
# ...
