# %%
import xarray as xr

# %%
ds = xr.open_dataset(f"CFS/PRESSURE/pgbf2026041206.01.2026041206.grb2", engine='cfgrib', backend_kwargs={"indexpath": ""}, filter_by_keys={'typeOfLevel': 'potentialVorticity'})

# %%
ds
# Out:
# <xarray.Dataset> Size: 84kB
# Dimensions:             (potentialVorticity: 2, latitude: 31, longitude: 56)
# Coordinates:
#     time                datetime64[ns] 8B ...
#     step                timedelta64[ns] 8B ...
#   * potentialVorticity  (potentialVorticity) float64 16B -2.147e+09 2e+03
#   * latitude            (latitude) float64 248B 20.0 21.0 22.0 ... 49.0 50.0
#   * longitude           (longitude) float64 448B 240.0 241.0 ... 294.0 295.0
#     valid_time          datetime64[ns] 8B ...
# Data variables:
#     u                   (potentialVorticity, latitude, longitude) float32 14kB ...
#     v                   (potentialVorticity, latitude, longitude) float32 14kB ...
#     t                   (potentialVorticity, latitude, longitude) float32 14kB ...
#     gh                  (potentialVorticity, latitude, longitude) float32 14kB ...
#     pres                (potentialVorticity, latitude, longitude) float32 14kB ...
# ...
