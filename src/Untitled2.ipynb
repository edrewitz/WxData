# %%
from wxdata.cfs.cfs import(
    cfs_flux,
    cfs_pressure
)

# %%
ds = cfs_pressure(western_bound=-125, 
                    eastern_bound=-65, 
                    northern_bound=50, 
                    southern_bound=20,
                    clear_data=True,
                    variables=['absolute vorticity'])
# Out:
# ...
# CFS Pressure Data Processing...
# CFS Pressure Data Processing Complete.

# %%
ds
# Out:
# <xarray.Dataset> Size: 18MB
# Dimensions:             (step: 65, isobaricInhPa: 37, latitude: 31,
#                          longitude: 61)
# Coordinates:
#     time                datetime64[ns] 8B ...
#   * step                (step) float64 520B 0.0 6.0 12.0 ... 372.0 378.0 384.0
#   * isobaricInhPa       (isobaricInhPa) float64 296B 1e+03 975.0 ... 2.0 1.0
#   * latitude            (latitude) float64 248B 20.0 21.0 22.0 ... 49.0 50.0
#     valid_time          datetime64[ns] 8B ...
#   * longitude           (longitude) float64 488B -125.0 -124.0 ... -66.0 -65.0
# Data variables:
#     absolute_vorticity  (step, isobaricInhPa, latitude, longitude) float32 18MB dask.array<chunksize=(1, 37, 31, 61), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.7
#     history:      2026-04-13T19:11 GRIB to CDM+CF via cfgrib-0.9.15.1/ecCodes...
