# %%
import xarray as xr

# %%
ds = xr.open_dataset(f"20260328T12Z_MSC_GDPS_DownwardShortwaveRadiationFlux-Accum_NTAtm_LatLon0.15_PT000H.grib2", engine='cfgrib')

# %%
ds
# Out:
# <xarray.Dataset> Size: 12MB
# Dimensions:     (latitude: 1201, longitude: 2400)
# Coordinates:
#     time        datetime64[ns] 8B ...
#     step        timedelta64[ns] 8B ...
#     nominalTop  float64 8B ...
#   * latitude    (latitude) float64 10kB -90.0 -89.85 -89.7 ... 89.7 89.85 90.0
#   * longitude   (longitude) float64 19kB 0.0 0.15 0.3 0.45 ... 359.5 359.7 359.9
#     valid_time  datetime64[ns] 8B ...
# Data variables:
#     tisr        (latitude, longitude) float32 12MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cwao
#     GRIB_centreDescription:  Canadian Meteorological Service - Montreal
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             Canadian Meteorological Service - Montreal
#     history:                 2026-03-29T20:46 GRIB to CDM+CF via cfgrib-0.9.1...
