# %%
from wxdata.fems.fems import(
    get_single_raws_station_weather_observations,
    get_single_raws_station_fuels_observations,
    get_multi_raws_station_weather_observations,
    get_multi_raws_station_fuels_observations,
    get_current_multi_raws_station_weather_observations,
    get_current_multi_raws_station_fuels_observations,
    get_current_all_raws_station_weather_observations,
    get_current_all_raws_station_fuels_observations,
    get_single_raws_station_nfdrs_forecast,
    get_multi_raws_station_nfdrs_forecast,
    get_single_raws_station_weather_forecast,
    get_multi_raws_station_weather_forecast
)
from wxdata.fems.meta_data import(
    get_single_raws_station_meta_data,
    get_multi_raws_station_meta_data
)

# %%
df, meta = get_multi_raws_station_weather_observations([45438, 451209])

# %%
df
# Out:
#         StationName                  DateTime ObservationType  Temperature(F)  \
# 167           ACTON  2026-04-01T05:00:00.000Z               O              53
# 230           ACTON  2026-04-03T20:00:00.000Z               O              66
# 228           ACTON  2026-04-03T18:00:00.000Z               O              62
# 227           ACTON  2026-04-03T17:00:00.000Z               O              60
# 226           ACTON  2026-04-03T16:00:00.000Z               O              59
# ..              ...                       ...             ...             ...
# 110  ABERNATHY MTN.  2026-04-05T19:00:00.000Z               O              61
# 109  ABERNATHY MTN.  2026-04-05T18:00:00.000Z               O              59
# 108  ABERNATHY MTN.  2026-04-05T17:00:00.000Z               O              56
# 107  ABERNATHY MTN.  2026-04-05T16:00:00.000Z               O              54
# 0    ABERNATHY MTN.  2026-04-01T05:00:00.000Z               O              39
#
#      RelativeHumidity(%)  Precipitation(in)  WindSpeed(mph)  \
# 167                   90               0.04             7.0
# 230                   13               0.00            19.0
# 228                   17               0.00            18.0
# 227                   20               0.00            21.0
# 226                   22               0.00            18.0
# ..                   ...                ...             ...
# 110                   42               0.00             5.0
# 109                   42               0.00             7.0
# 108                   48               0.00             7.0
# 107                   51               0.00             6.0
# 0                    100               0.01             7.0
#
#      WindAzimuth(degrees)  GustSpeed(mph)  GustAzimuth(degrees)  SnowFlag  \
# 167                    16              13                    15         0
# 230                    43              36                    18         0
# 228                    37              44                    41         0
# 227                    38              37                    49         0
# 226                    44              41                    38         0
# ..                    ...             ...                   ...       ...
# 110                    90               9                    62         0
# 109                    77              10                    61         0
# 108                    58              11                    56         0
# 107                    31              10                    27         0
# 0                     186              15                   174         0
#
#      SolarRadiation(W/m2)  Tflag  RHflag  PCPflag  WSflag  WAflag  SRflag  \
# 167                     0    NaN     NaN      NaN     NaN     NaN     NaN
# 230                   843    NaN     NaN      NaN     NaN     NaN     NaN
# 228                   672    NaN     NaN      NaN     NaN     NaN     NaN
# 227                   508    NaN     NaN      NaN     NaN     NaN     NaN
# 226                   277    NaN     NaN      NaN     NaN     NaN     NaN
# ..                    ...    ...     ...      ...     ...     ...     ...
# 110                   551    NaN     NaN      NaN     NaN     NaN     NaN
# 109                   551    NaN     NaN      NaN     NaN     NaN     NaN
# 108                   340    NaN     NaN      NaN     NaN     NaN     NaN
# 107                   192    NaN     NaN      NaN     NaN     NaN     NaN
# 0                       0    NaN     NaN      NaN     NaN     NaN     NaN
#
#      GSflag  GAflag
# 167     NaN     NaN
# 230     NaN     NaN
# 228     NaN     NaN
# 227     NaN     NaN
# 226     NaN     NaN
# ..      ...     ...
# 110     NaN     NaN
# 109     NaN     NaN
# 108     NaN     NaN
# 107     NaN     NaN
# 0       NaN     NaN
#
# [334 rows x 20 columns]

# %%
meta
# Out:
#   Goober Reason  station_id wrcc_id period_record_start period_record_stop  \
# 0           NaN       45438    CACT          2005-01-01         2022-12-31
# 1           NaN      451209    WABE          2005-01-01         2022-12-31
#
#   nesdis_id    station_name state       county   latitude  ...      region  \
# 0  CA4A7044           ACTON    CA  Los Angeles  34.446389  ...  CALIFORNIA
# 1  3000B5D0  ABERNATHY MTN.    WA      Cowlitz  46.342778  ...  WASHINGTON
#
#                    unit transmit_time tx_frequency obs_frequency  \
# 0    LOS ANGELES COUNTY      2.284722           60            60
# 1  DEPT. OF NATURAL RES      0.069444           60            60
#
#                                     site_description  goes  \
# 0  Northside of San Gabriels, in foothills of Pin...  West
# 1                                                NaN  West
#
#   maintenance_standard  time_zone  avg_annual_precip
# 0                  Yes        PST              10.56
# 1                  Yes        PST              84.90
#
# [2 rows x 25 columns]

# %%
import pandas as pd

# %%
meta = pd.read_excel(f"FEMS Data/Station Meta Data/RAWS Meta Data.xlsx", sheet_name='Sheet1')
