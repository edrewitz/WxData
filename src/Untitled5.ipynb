# %%
from wxdata.fems.fems import(
    get_single_raws_station_observations,
    get_multi_raws_station_observations,
    get_current_multi_raws_station_observations,
    get_single_raws_station_nfdrs_forecast,
    get_multi_raws_station_nfdrs_forecast
)

from wxdata.fems.meta_data import(
    get_single_raws_station_meta_data,
    get_multi_raws_station_meta_data
)

# %%
df = get_current_multi_raws_station_observations([45438, 40635, 451415])

# %%
df
# Out:
#      stationName           observationTime NFDRType fuelModelType  \
# 44         SUMAS  2026-04-01T21:00:00.000Z        F             Y
# 22  OAK MOUNTAIN  2026-04-01T21:00:00.000Z        F             Y
# 67         ACTON  2026-04-01T21:00:00.000Z        F             Y
#
#     oneHR_TL_FuelMoisture  tenHR_TL_FuelMoisture  hundredHR_TL_FuelMoisture  \
# 44                  35.00                  30.90                      20.73
# 22                  35.00                  34.95                      20.52
# 67                  11.21                  18.61                      16.82
#
#     thousandHR_TL_FuelMoisture   kbdi   gsi  woodyLFI_fuelMoisture  \
# 44                       23.67    NaN  0.15                     60
# 22                       12.32  335.0  0.28                     60
# 67                       14.11  753.0  0.00                     60
#
#     herbaceousLFI_fuelMoisture  ignitionComponent  energyReleaseComponent  \
# 44                          30               0.00                    0.00
# 22                          30               0.00                   13.38
# 67                          30              15.04                   28.74
#
#     spreadComponent  burningIndex  NFDRQAFlag   latitude   longitude
# 44             0.00          0.00           0  48.907744 -122.223383
# 22             0.00          0.00           0  41.006331 -121.984431
# 67             4.06         26.87           0  34.446389 -118.196800
