# %%
import requests
from io import StringIO
from bs4 import BeautifulSoup

# %%
response = requests.get("https://wildfireweb-prod-media-bucket.s3.us-gov-west-1.amazonaws.com/s3fs-public/2025-07/FEMS_3.0_RAWS_Master_Station_List_and_Metadata.xlsx")
