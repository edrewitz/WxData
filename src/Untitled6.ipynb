# %%
import requests

# 1. Parse the bucket and prefix from your URL
bucket = "ecmwf-open-data"
# Your path: 20260510/18z/ifs/0p25/scda/
prefix = "20260510/18z/ifs/0p25/scda/"

# %%
url = f"https://ecmwf-forecasts.s3.eu-central-1.amazonaws.com/{prefix}"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [404]>
