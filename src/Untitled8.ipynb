# %%
import wxdata.client as client

# %%
client.get_gridded_data(f"https://ecmwf-forecasts.s3.eu-central-1.amazonaws.com/20260511/00z/ifs/0p25/oper/20260511000000-0h-oper-fc.grib2",
                        f"EC",
                        f"20260511000000-0h-oper-fc.grib2")
# Out:
# 20260511000000-0h-oper-fc.grib2:   0%|          | 0.00/121M [00:00<?, ?B/s]
# Successfully saved 20260511000000-0h-oper-fc.grib2 to f:EC
